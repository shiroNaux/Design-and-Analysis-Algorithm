# %%
arr = []

# %%
def subArray(array):
    dynamic = [1] * len(array)
    i = 1
    maximum = array[0]
    sub = 1
    while(i < len(array)):
        if array[i] > maximum:
            dynamic[i] = sub + 1
            sub = dynamic[i]
            maximum = array[i]
        else:
            result = list()
            for j in range(0,i):
                if array[i] > array[j]:
                    result.append(dynamic[j])
                dynamic[i] = max(result) + 1
        
        i += 1
    return dynamic

# %%
arr = [2,5,4,6,3,8,9,7]

# %%
A = subArray(arr)

# %%
A
# Out:
# [1, 2, 2, 3, 2, 4, 5, 4]

# %%
def rollback(matrix):
    re = list()
    maximim = max(matrix)
    for i in range(len(matrix) - 1, -1, -1):
        if matrix[i] == maximum:
            re.append(arr[i])
            maximum -= 1
    return re
